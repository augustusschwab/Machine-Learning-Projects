# %% [markdown]
# # University Clusters - K Means Clustering Project
#
# This project is an examination of the process for generating a K means clustering model. It is performed on a dataset composed of various features of university students. There will be two clusters generated in an attempt to distinguish private and public school students. There is a unique component to the project where clusters generated are tested against the private column in the dataset. This is not typical for a K means clustering model because they are unsupervised algorithms.
#
# The dataset is composed of the following variables:
# * Private: A factor with levels No and Yes indicating private or public university
# * Apps: Number of applications received
# * Accept: Number of applications accepted
# * Enroll: Number of new students enrolled
# * Top10perc: Pct. new students from top 10% of H.S. class
# * Top25perc: Pct. new students from top 25% of H.S. class
# * F.Undergrad: Number of fulltime undergraduates
# * P.Undergrad: Number of parttime undergraduates
# * Outstate: Out-of-state tuition
# * Room.Board: Room and board costs
# * Books: Estimated book costs
# * Personal: Estimated personal spending
# * PhD: Pct. of faculty with Ph.D.’s
# * Terminal: Pct. of faculty with terminal degree
# * S.F.Ratio: Student/faculty ratio
# * perc.alumni: Pct. alumni who donate
# * Expend: Instructional expenditure per student
# * Grad.Rate: Graduation rate
# ___

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# **Data Analysis**
#
# Here I read in the the dataset from the csv file and set the index to the college name. The contents of the data are examined via .head(), .info(), and .describe(). These three commands are performed to understand the data types, quantity of data, as well as general statistical measurements of the observations.

# %%
data = pd.read_csv('College_Data', index_col=0)

# %%
data.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
data.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
# Private        777 non-null object
# Apps           777 non-null int64
# Accept         777 non-null int64
# Enroll         777 non-null int64
# Top10perc      777 non-null int64
# Top25perc      777 non-null int64
# F.Undergrad    777 non-null int64
# P.Undergrad    777 non-null int64
# Outstate       777 non-null int64
# Room.Board     777 non-null int64
# Books          777 non-null int64
# Personal       777 non-null int64
# PhD            777 non-null int64
# Terminal       777 non-null int64
# S.F.Ratio      777 non-null float64
# perc.alumni    777 non-null int64
# Expend         777 non-null int64
# Grad.Rate      777 non-null int64
# dtypes: float64(1), int64(16), object(1)
# memory usage: 115.3+ KB

# %% [markdown]
# ___
# **Data Visualization**
#
# This is done to get a quick understanding of relationships that are in the dataset. This step is critical to understanding the best algorithm for the solution, however for this project the algorithm was decided in advance.
#
# The first two plots are scatterplots of the graduation rate vs. room and board costs and the fulltime students vs. out of state tuition cost both separated by school type (private or public). The goal here is to try to find some sort of separation in the data. The separation in the second scatterplot is quite drastic, however as is shown later K Means clustering doesn't pick up on this separation.
#
# Next two different histograms are visualized the first is the frequency of out of state tuition prices for private and non-private students indicating private students have higher out of state tuition costs. Second, the frequency of graduation rates for private and non-private students are shown, the central tendency for graduation rate for private students is about 10% higher than public school students.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Grad.Rate', y='Room.Board', data=data, hue='Private')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='F.Undergrad', y='Outstate', data=data, hue='Private')

# %%
g = sns.FacetGrid(data, hue='Private', height=6, aspect=2, palette='coolwarm')
g.map(plt.hist, 'Outstate', alpha=0.7, bins=30)
plt.ylabel('Number of Students')
plt.legend()
plt.title('Frequency of Out of State Tuition Prices for Private and Non-Private Students')
# Out:
# Text(0.5, 1.0, 'Frequency of Out of State Tuition Prices for Private and Non-Private Students')

# %%
g = sns.FacetGrid(data, hue='Private', height=6, aspect=2, palette='coolwarm')
g.map(plt.hist, 'Grad.Rate', alpha=0.7, bins=30)
plt.ylabel('Number of Students')
plt.legend()
plt.title('Frequency of Graduation Rates for Private and Non-Private Students')
# Out:
# Text(0.5, 1.0, 'Frequency of Graduation Rates for Private and Non-Private Students')

# %% [markdown]
# **Cleaning**
#
# Notice there is a graduation rate outside of 100% in the histogram above, which is not realistic. This is fixed by assuming the graduation rate is 100%. It is found, changed and then checked.

# %%
data[data['Grad.Rate']>100]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate
# Cazenovia College        118

# %%
data['Grad.Rate']['Cazenovia College'] = 100
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data[data['Grad.Rate']>100]
# Out:
# Empty DataFrame
# Columns: [Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %%
g = sns.FacetGrid(data, hue='Private', height=6, aspect=2, palette='coolwarm')
g.map(plt.hist, 'Grad.Rate', alpha=0.7, bins=30)
plt.ylabel('Number of Students')
plt.legend()
plt.title('Frequency of Graduation Rates for Private and Non-Private Students')
# Out:
# Text(0.5, 1.0, 'Frequency of Graduation Rates for Private and Non-Private Students')

# %% [markdown]
# ___
# **Training K Means Cluster Model**
#
# This is an unsupervised learning model, so the data will only have features and conclusions will be drawn from them. The model chosen is a K Means Cluster model, which is an algorithm that seeks to partition the observations into a prespecified number of clusters K (in this case 2). It does this by randomy assigning a number from 1 to K to each observation, these are initial cluster assignments. For each of the clusters it computes the centroid and then reassigns each observation based on the cluster that is closest until the observations stop changing.

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(data.drop('Private', axis=1))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# The model converged in 17 iterations

# %%
kmeans.cluster_centers_
# Out:
# array([[1.03631389e+04, 6.55089815e+03, 2.56972222e+03, 4.14907407e+01,
#         7.02037037e+01, 1.30619352e+04, 2.46486111e+03, 1.07191759e+04,
#         4.64347222e+03, 5.95212963e+02, 1.71420370e+03, 8.63981481e+01,
#         9.13333333e+01, 1.40277778e+01, 2.00740741e+01, 1.41705000e+04,
#         6.75925926e+01],
#        [1.81323468e+03, 1.28716592e+03, 4.91044843e+02, 2.53094170e+01,
#         5.34708520e+01, 2.18854858e+03, 5.95458894e+02, 1.03957085e+04,
#         4.31136472e+03, 5.41982063e+02, 1.28033632e+03, 7.04424514e+01,
#         7.78251121e+01, 1.40997010e+01, 2.31748879e+01, 8.93204634e+03,
#         6.50926756e+01]])

# %% [markdown]
# **Model Evaluation**
#
# In general this is not a step when using unsupervised learning algorithms, the main reason for using unsupervised learning is to generate analysis of the data. However here the project is looking at the effectiveness of K means clustering for separating out the students into private and public classes.
#
# The first method of evaluation was recreating the two histograms above using the labels generated from the model. It looks like the model overlabelled students as private (private = 1), this is quite evident in the histogram that shows frequency of out of state tuition prices. The lower price ranges see a higher frequency of private students from the model.
#
# To confirm this a confusion matrix and classification report are generated, comparing the original classification of private and the model classifications. The model mislabelled 172 data points for a weighted f1-score of 75, this is poor classification.

# %%
labels = pd.DataFrame(kmeans.labels_, index=data.index)
cluster_df = pd.concat([data, labels], axis=1)

# %%
g = sns.FacetGrid(cluster_df, hue=0, height=6, aspect=2, palette='coolwarm')
g.map(plt.hist, 'Outstate', alpha=0.7, bins=30)
plt.ylabel('Number of Students')
plt.legend()
plt.title('Frequency of Out of State Tuition Prices for K Means Clusters 0 and 1')
# Out:
# Text(0.5, 1.0, 'Frequency of Out of State Tuition Prices for K Means Clusters 0 and 1')

# %%
g = sns.FacetGrid(cluster_df, hue=0, height=6, aspect=2, palette='coolwarm')
g.map(plt.hist, 'Grad.Rate', alpha=0.7, bins=30)
plt.ylabel('Number of Students')
plt.legend()
plt.title('Frequency of Graduation Rates for K Means Clusters 0 and 1')
# Out:
# Text(0.5, 1.0, 'Frequency of Graduation Rates for K Means Clusters 0 and 1')

# %%
#Function to convert private column to 0 and 1 instead of No and Yes.
def converter(label):
    if label == 'No':
        return 0
    else:
        return 1

# %%
data['Private_Convert'] = data['Private'].apply(converter)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(data.Private_Convert, cluster_df[0]))
print('\n')
print(classification_report(data.Private_Convert, cluster_df[0]))
# Out:
# [[ 74 138]
#  [ 34 531]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.35      0.46       212
#            1       0.79      0.94      0.86       565
#
#    micro avg       0.78      0.78      0.78       777
#    macro avg       0.74      0.64      0.66       777
# weighted avg       0.76      0.78      0.75       777

# %% [markdown]
# **Reducing Features**
#
# Finally, looking at the scatterplot that had a drastic separation from the original dataset and isolating those features doesn't improve the classification. In fact the labels switched. In this case the groups it recognized recieved labels opposite to the model trained above. However, The model still misclassifies the data as is seen in the scatterplot below.

# %%
new_kmeans = KMeans(n_clusters = 2)
new_kmeans.fit(data[['Outstate','F.Undergrad']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
new_labels = pd.DataFrame(new_kmeans.labels_, index=data.index)
new_cluster_df = pd.concat([data, labels], axis=1)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='F.Undergrad', y='Outstate', data=new_cluster_df, hue=0)

# %% [markdown]
# ___
# **Conclusion**
#
# K means clustering is a unique way of drawing conclusions from datasets by grouping clusters of observations together. This can be valuable for drawing insights from data that seems to be unrelated. In the dataset used for this project we were provide with the labels of the two groups, but in reality this won't be the case. Actually, you probably won't know if unique groupings exist in the data, that is why Kmeans clustering is used. However, I was able to show how K means clustering is implemented and evaluate how well it distinguished the two groups of students (private and public).
